# %%
import wfdb
import numpy as np
import matplotlib.pyplot as plt

# %%
data = wfdb.io.rdrecord("rec_1")
signal = data.adc()[:, 0]

# %%
data.fs
# Out:
# 500

# %%
plt.plot(...)

# %%
noise = np.sin(np.linspace(0, 20, 10_000) * 2 * np.pi * 50)

# %%
plt.plot(signal + noise * 70 - noise * 70)

# %%
plt.plot(np.sin(np.linspace(0, 20, 10_000) * 2 * np.pi * 50)[:1000])
